# %%
from src.preprocessing.preprocess_files import DataPreprocessor

# Ruta al archivo PDF
pdf_path = '00417- 24- CIRILLO Mercedez-.pdf'

# Leer el contenido del PDF
with open(pdf_path, 'rb') as file:
    pdf_content = file.read()

# Preprocesar el PDF para obtener imágenes en Base64
preprocessor = DataPreprocessor(pdf_content)
images_base64 = preprocessor()

# Verificar el número de imágenes codificadas en Base64 generadas
print(f"Se generaron {len(images_base64)} imágenes en Base64.")
# Out:
# Se generaron 13 imágenes en Base64.

# %%
import os 
os.environ['AZURE_OPENAI_API_KEY'] = 'fc3fb425ea0f465e87ab19d89c0e088'
os.environ['AZURE_OPENAI_ENDPOINT'] = 'https://gpp.openai.azure.com/'
from dotenv import load_dotenv
load_dotenv(".env.dev")

from src.data_extractor.extract_data import extract_data_from_image
result = extract_data_from_image(images_base64)
result
# Out:
# c:\Users\ezean\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\base.py:994: UserWarning: Streaming with Pydantic response_format not yet supported.
#   warnings.warn("Streaming with Pydantic response_format not yet supported.")
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[5], line 8
#       5 load_dotenv(".env.dev")
#       7 from src.data_extractor.extract_data import extract_data_from_image
# ----> 8 result = extract_data_from_image(images_base64)
#       9 result
#
# File c:\Users\ezean\OneDrive\Escritorio\tesis_ant\src\data_extractor\extract_data.py:36, in extract_data_from_image(images)
#      34 def extract_data_from_image(images: List[str]):
# ---> 36     llm_data = __extract_data_from_image_llm(images)
#      37     return {
#      38         'quantitative_data': llm_data['quantitative_data'],
# ...

# %%
import os 
os.environ['AZURE_OPENAI_API_KEY'] = 'fc3fb425ea0f465e87ab19d89c0e088'
os.environ['AZURE_OPENAI_ENDPOINT'] = 'https://gpp.openai.azure.com/'
from dotenv import load_dotenv
load_dotenv(".env.dev")

from src.data_extractor.extract_data import __extract_plots_from_image
result = __extract_plots_from_image(images_base64)
result
display(result)
# Out:
# [<PIL.Image.Image image mode=RGB size=920x420>,
#  <PIL.Image.Image image mode=RGB size=910x300>,
#  <PIL.Image.Image image mode=RGB size=440x160>,
#  <PIL.Image.Image image mode=RGB size=440x160>,
#  <PIL.Image.Image image mode=RGB size=440x160>,
#  <PIL.Image.Image image mode=RGB size=450x160>,
#  <PIL.Image.Image image mode=RGB size=440x160>,
#  <PIL.Image.Image image mode=RGB size=440x160>,
#  <PIL.Image.Image image mode=RGB size=915x820>,
#  <PIL.Image.Image image mode=RGB size=915x820>,
#  <PIL.Image.Image image mode=RGB size=915x890>,
#  <PIL.Image.Image image mode=RGB size=915x790>,
#  <PIL.Image.Image image mode=RGB size=915x790>,
#  <PIL.Image.Image image mode=RGB size=915x790>,
#  <PIL.Image.Image image mode=RGB size=915x790>]

# %%
# Nota 2: Extraer gráficos y mostrar imágenes
import os
from dotenv import load_dotenv
from src.data_extractor.extract_data import __extract_plots_from_image
from IPython.display import display
from PIL import Image

# Configuración de claves
os.environ['AZURE_OPENAI_API_KEY'] = 'fc3fb425ea0f465e87ab19d89c0e088'
os.environ['AZURE_OPENAI_ENDPOINT'] = 'https://gpp.openai.azure.com/'
load_dotenv(".env.dev")

# Extraer gráficos
result = __extract_plots_from_image(images_base64)

# Mostrar imágenes recortadas
if result:
    for idx, img in enumerate(result):
        print(f"Gráfico {idx + 1}:")
        display(img)
else:
    print("No se encontraron gráficos recortados.")
# Out:
# Gráfico 1:
# <PIL.Image.Image image mode=RGB size=920x420>
# Gráfico 2:
# <PIL.Image.Image image mode=RGB size=910x300>
# Gráfico 3:
# <PIL.Image.Image image mode=RGB size=440x160>
# Gráfico 4:
# <PIL.Image.Image image mode=RGB size=440x160>
# Gráfico 5:
# <PIL.Image.Image image mode=RGB size=440x160>
# Gráfico 6:
# <PIL.Image.Image image mode=RGB size=450x160>
# Gráfico 7:
# <PIL.Image.Image image mode=RGB size=440x160>
# Gráfico 8:
# <PIL.Image.Image image mode=RGB size=440x160>
# Gráfico 9:
# <PIL.Image.Image image mode=RGB size=915x820>
# Gráfico 10:
# <PIL.Image.Image image mode=RGB size=915x820>
# Gráfico 11:
# <PIL.Image.Image image mode=RGB size=915x890>
# Gráfico 12:
# <PIL.Image.Image image mode=RGB size=915x790>
# Gráfico 13:
# <PIL.Image.Image image mode=RGB size=915x790>
# Gráfico 14:
# <PIL.Image.Image image mode=RGB size=915x790>
# Gráfico 15:
# <PIL.Image.Image image mode=RGB size=915x790>
