# %%
from src.common.gdrive_manager import Downloader

# %%
drive = Downloader()
drive.getAllFiles("15uTculTCM1I7cMekxunUd7LnP2AsLTI0" )
# Out:
# Adding file: drive_content\00411- 24- DEMICHELLI Diego\run 411\run 2.pdf
# Adding file: drive_content\00411- 24- DEMICHELLI Diego\run 411\20240302_113214Report.pdf
# Adding file: drive_content\00411- 24- DEMICHELLI Diego\run 411\run 3.pdf
# Adding file: drive_content\00411- 24- DEMICHELLI Diego\run 411\run 2 g-se.pdf
# Adding file: drive_content\00411- 24- DEMICHELLI Diego\00411- 24- DEMICHELLI Diego-.pdf
# Adding file: drive_content\00410- 24- SINGER Alejandro\run 410\run 2 g-se.pdf
# Adding file: drive_content\00410- 24- SINGER Alejandro\run 410\20240216_204545Report.pdf
# Adding file: drive_content\00410- 24- SINGER Alejandro\run 410\run 3.pdf
# Adding file: drive_content\00410- 24- SINGER Alejandro\run 410\run 2.pdf
# Adding file: drive_content\00410- 24- SINGER Alejandro\00410- 24- SINGER Alejandro-.pdf
# Adding file: drive_content\00409- 24- DE BERNARDI Gustavo\Run 409\run 2 -g-se.pdf
# Adding file: drive_content\00409- 24- DE BERNARDI Gustavo\Run 409\run 1.pdf
# ...

# %%
fr
